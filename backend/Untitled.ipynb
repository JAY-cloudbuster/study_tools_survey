# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('final_dataset_clean.csv')

# %%
df.isna().sum()
# Out:
# observation_id                       0
# cohort_key                           0
# response_timestamp_x                 0
# week_number                          0
# total_hours_this_week                0
# avg_daily_study_hours                0
# study_consistency                    0
# revision_frequency                   0
# group_study_participation            0
# ai_tools_usage                      75
# approx_ai_usage_hours                0
# digital_tool_usage_frequency         0
# academic_constraints_raw          1722
# productivity_level                   0
# stress_level                         0
# had_assessment                       0
# assessment_score                     0
# comparison_to_last_week              0
# weekly_tools_raw                   207
# response_timestamp_y                 0
# state                                0
# university_type                      0
# course_program                       0
# year_of_study                        0
# ...
